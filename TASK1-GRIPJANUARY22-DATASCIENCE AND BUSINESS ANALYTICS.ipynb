# %% [markdown]
# # AUTHOR: LAKSHMI VYSHNAVI UMMADISETTI

# %% [markdown]
# # TASK1 - PREDICTION USING SUPERVISED ML

# %% [markdown]
# # DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP - THE SPARKS FOUNDATION (GRIPJANUARY22)

# %% [markdown]
# # USING SIMPLE LINEAR REGRESSION TO PREDICT THE PERCENTAGE OF MARKS A STUDENT IS EXPECTED TO SCORE BASED UPON NUMBER OF HOURS THEY STUDIED.

# %%
#IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
# Reading data from remote link
url = "http://bit.ly/w-data"
data = pd.read_csv(url)
print("Data imported successfully")
print(s_data.shape)
data.head(10)
# Out:
# Data imported successfully
# (25, 2)
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30
# 5    1.5      20
# 6    9.2      88
# 7    5.5      60
# 8    8.3      81
# 9    2.7      25

# %%
#to find information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
# Statistical summary of data frame 'df'
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# # Plotting the distribution of scores(visualising)

# %%
data.plot(x='Hours', y='Scores', style='o')  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %% [markdown]
# From the graph above, we can clearly see that there is a positive linear relation between the number of hours studied and percentage of score.

# %%
data.plot(x = 'Hours',y = 'Scores',linestyle = '--',marker = 'o',markersize = '9',markerfacecolor = 'red', figsize=(8,6))
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Scored')
# Out:
# Text(0, 0.5, 'Percentage Scored')

# %%
# Correlation plot - Heatmap
import seaborn as sns
plt.title('Heatmap')
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# # Preparing the data
# Dividing the data into "attributes" (inputs) and "labels" (outputs)

# %%
X = data.iloc[:, :-1].values  
y = data.iloc[:, 1].values

# %% [markdown]
# # Spliting this data into training and test sets
# Splitting the data to training and testing datasets.

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=0)

# %% [markdown]
# # Training the Algorithm

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 

print("Training complete.")
# Out:
# Training complete.

# %%
# Plotting the regression line
line = regressor.coef_*X+regressor.intercept_

# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, line);
plt.plot (X, line, color = 'Red')
plt.show()

# %% [markdown]
# # Making Predictions

# %%
print(X_test) # Testing data - In Hours
y_pred = regressor.predict(X_test) # Predicting the scores
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]

# %%
# Comparing Actual vs Predicted
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# Line Graph
data.plot(kind='line', figsize=(8,6), color=['green','blue'] ,title ='Comaparison between Actual and Predicted Score Values')
plt.show()

# %%
# Bar Graph
data.plot(kind='bar',figsize=(8,6), color=['Red', 'blue'], title= 'Comaparison between Actual and Predicted Score Values')
# Out:
# <AxesSubplot:title={'center':'Comaparison between Actual and Predicted Score Values'}>

# %% [markdown]
# # Estimating training and test score
# Checking the accuracy of the model

# %%
print("Training Score:",regressor.score(X_train,y_train))
print("Test Score:",regressor.score(X_test,y_test))
# Out:
# Training Score: 0.9515510725211552
# Test Score: 0.9454906892105355

# %% [markdown]
# # Predicting the score if the student studies for 9.5 hours/day

# %%
hours = 9.25
pred = regressor.predict([[hours]])
print("Predicted Score is",pred[0])
# Out:
# Predicted Score is 93.69173248737535

# %% [markdown]
# # Evaluating the model
# This step is particularly important to compare how well different algorithms perform on a particular dataset.

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred)) 
print('Mean Squared Error:', 
      metrics.mean_squared_error(y_test, y_pred)) 
print('Root Mean Squared Error:',
      np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 4.183859899002975
# Mean Squared Error: 21.598769307217406
# Root Mean Squared Error: 4.647447612100367

# %% [markdown]
# Conclusion - Predicted the score of student studying for 9.25 hrs using linear regression is 93.69 marks and the model is good because the metrics are too low
